# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

from plotting_helpers import *

# %%
#get 1 state data and extract summary stats
random_1 = pd.read_csv("random_edges/vary_edges/25_1_10.csv")
random_1_avg, random_1_std = perf_summary_stats(random_1)

pruned_1 = pd.read_csv("pruned_edges/vary_edges/25_1_10.csv")
pruned_1_avg, pruned_1_std = perf_summary_stats(pruned_1)

# %%
#plots variation of info against retrievability for pruned graph
plt.scatter(pruned_1_avg["variation_of_information"], pruned_1_avg["retrievability"])
plt.xlabel("Variation of Information")
plt.ylabel("Retrievability");

# %% [markdown]
# Good that there is some coherant relationship between the two, but am very unsure what is going on in the bottom right porition. Seems like that could be the cause for the inverted U at low edge values in the performance plots. For now, I'll just consider all performance metrics in analysis to be safe.

# %%
#plots variation of info
plt.plot(random_1_avg.index, random_1_avg["variation_of_information"], label = "Random edges")
plt.plot(pruned_1_avg.index, pruned_1_avg["variation_of_information"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Variation of Information")
plt.title("25 Nodes, 1 Stored State")
plt.legend()

# %%
#plots retrievability
plt.plot(random_1_avg.index, random_1_avg["retrievability"], label = "Random edges")
plt.plot(pruned_1_avg.index, pruned_1_avg["retrievability"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Retrievability")
plt.title("25 Nodes, 1 Stored State")
plt.legend()

# %%
#plots stability
plt.plot(random_1_avg.index, random_1_avg["stability"], label = "Random edges")
plt.plot(pruned_1_avg.index, pruned_1_avg["stability"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Stability")
plt.title("25 Nodes, 1 Stored State")
plt.legend()

# %%
#same for 2 state data
random_2 = pd.read_csv("random_edges/vary_edges/25_2_100.csv")
random_2_avg, random_2_std = perf_summary_stats(random_2)

pruned_2 = pd.read_csv("pruned_edges/vary_edges/25_2_100.csv")
pruned_2_avg, pruned_2_std = perf_summary_stats(pruned_2)

# %%
#plots variation of info
plt.plot(random_2_avg.index, random_2_std["variation_of_information"], label = "Random edges")
plt.plot(pruned_2_avg.index, pruned_2_std["variation_of_information"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Variation of Information")
plt.title("25 Nodes, 2 Stored State")
plt.legend()

# %% [markdown]
# - Look at dist of perf at fixed edge count.
# - For fixed number of edges, plot perf vs mutual info of stored states.
# Questions about the topology of the graph:
# - Laplacian of the adj. matrix
#      - Spectrum of eigenvalues to pick out community structure
#      - draw out the layouts

# %%
#plots retrievability
plt.plot(random_2_avg.index, random_2_avg["retrievability"], label = "Random edges")
plt.plot(pruned_2_avg.index, pruned_2_avg["retrievability"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Retrievability")
plt.title("25 Nodes, 2 Stored State")
plt.legend()

# %%
#plots stability
plt.plot(random_2_avg.index, random_2_avg["stability"], label = "Random edges")
plt.plot(pruned_2_avg.index, pruned_2_avg["stability"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Stability")
plt.title("25 Nodes, 2 Stored State")
plt.legend()

# %%
#same for 3 state data
random_3 = pd.read_csv("random_edges/vary_edges/25_3_10.csv")
random_3_avg, random_1_std = perf_summary_stats(random_3)

pruned_3 = pd.read_csv("pruned_edges/vary_edges/25_3_10.csv")
pruned_3_avg, pruned_2_std = perf_summary_stats(pruned_3)

# %%
#plots variation of info
plt.plot(random_3_avg.index, random_3_avg["variation_of_information"], label = "Random edges")
plt.plot(pruned_3_avg.index, pruned_3_avg["variation_of_information"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Variation of Information")
plt.title("25 Nodes, 3 Stored State")
plt.legend()

# %%
#plots retrievability
plt.plot(random_3_avg.index, random_3_avg["retrievability"], label = "Random edges")
plt.plot(pruned_3_avg.index, pruned_3_avg["retrievability"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Retrievability")
plt.title("25 Nodes, 3 Stored State")
plt.legend()

# %%
#plots stability
plt.plot(random_3_avg.index, random_3_avg["stability"], label = "Random edges")
plt.plot(pruned_3_avg.index, pruned_3_avg["stability"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Stability")
plt.title("25 Nodes, 3 Stored State")
plt.legend()

# %% [markdown]
# So it seems performance is notably better for pruned edges with stored states > 1. Now want to look at runtime as well.

# %%
random_2 = pd.read_csv("random_edges/vary_edges/25_2_10.csv")
random_2_avg, random_1_std = perf_summary_stats(random_2)

pruned_2 = pd.read_csv("pruned_edges/vary_edges/25_2_10.csv")
pruned_2_avg, pruned_2_std = perf_summary_stats(pruned_2)

# %%
#plots variation of info
plt.plot(random_2_avg.index, random_2_avg["variation_of_information"], label = "Random edges")
plt.plot(pruned_2_avg.index, pruned_2_avg["variation_of_information"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Variation of Information")
plt.title("25 Nodes, 2 Stored State")
plt.legend()

# %%
#plots runtime
plt.plot(random_2_avg.index, random_2_avg["runtime"], label = "Random edges")
plt.plot(pruned_2_avg.index, pruned_2_avg["runtime"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Runtime")
plt.title("25 Nodes, 2 Stored State")
plt.legend()

# %% [markdown]
# Doesn't seem to be a huge difference, but I think this might get more exagerated with more nodes. I'll try runnint 100 nodes with 5 stored states.

# %%
random_100_5 = pd.read_csv("random_edges/vary_edges/100_5_10.csv")
random_100_5_avg, random_100_5_std = perf_summary_stats(random_100_5)

pruned_100_5 = pd.read_csv("pruned_edges/vary_edges/100_5_10.csv")
pruned_100_5_avg, pruned_100_5_std = perf_summary_stats(pruned_100_5)

# %%
#plots variation of info
plt.plot(random_100_5_avg.index, random_100_5_avg["variation_of_information"], label = "Random edges")
plt.plot(pruned_100_5_avg.index, pruned_100_5_avg["variation_of_information"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Variation of Information")
plt.title("100 Nodes, 5 Stored State")
plt.legend()

# %%
#plots runtime
plt.plot(random_100_5_avg.index, random_100_5_avg["runtime"], label = "Random edges")
plt.plot(pruned_100_5_avg.index, pruned_100_5_avg["runtime"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Runtime")
plt.title("100 Nodes, 5 Stored State")
plt.legend()

# %% [markdown]
# Going to now do the same for 10 stored states to see how perf scales.

# %%
random_100_10 = pd.read_csv("random_edges/vary_edges/100_10_10.csv")
random_100_10_avg, random_100_10_std = perf_summary_stats(random_100_10)

pruned_100_10 = pd.read_csv("pruned_edges/vary_edges/100_10_10.csv")
pruned_100_10_avg, pruned_100_10_std = perf_summary_stats(pruned_100_10)

# %%
#plots variation of info
plt.plot(random_100_10_std.index, random_100_10_std["variation_of_information"], label = "Random edges")
plt.plot(pruned_100_10_std.index, pruned_100_10_std["variation_of_information"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Variation of Information")
plt.title("100 Nodes, 10 Stored State")
plt.legend()

# %%
#plots runtime
plt.plot(random_100_10_avg.index, random_100_10_avg["runtime"], label = "Random edges")
plt.plot(pruned_100_10_avg.index, pruned_100_10_avg["runtime"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Runtime")
plt.title("100 Nodes, 10 Stored State")
plt.legend()

# %% [markdown]
# Now scatter average variation of info in states against variation of info in results.

# %%
random_states_50_200 = pd.read_csv("random_edges/vary_states/50_5_200_30.csv")
pruned_states_50_200 = pd.read_csv("pruned_edges/vary_states/50_5_200_30.csv")

# %%
random_states_50_200.head()
# Out:
#    Mutual Information of States  variation_of_information  retrievability
# 0                           0.0                  0.115469         1.00000
# 1                           0.0                  0.049308         0.53328
# 2                           0.0                  0.322972         1.00000
# 3                           0.0                  0.365536         1.00000
# 4                           0.0                  0.037737         1.00000

# %%
#scatter the random data
plt.scatter(random_states_50_200["Mutual Information of States"], random_states_50_200["variation_of_information"], label="random")
plt.scatter(pruned_states_50_200["Mutual Information of States"], pruned_states_50_200["variation_of_information"], label = "pruned")
plt.legend()

# %%
#scatter the random data
plt.scatter(random_states_50_200["Mutual Information of States"], random_states_50_200["retrievability"], label="random")
plt.scatter(pruned_states_50_200["Mutual Information of States"], pruned_states_50_200["retrievability"], label = "pruned")
plt.legend()

# %% [markdown]
# Now increase the count of edges to see how these plots change

# %%
random_states_50_300 = pd.read_csv("random_edges/vary_states/50_5_300_30.csv")
pruned_states_50_300 = pd.read_csv("pruned_edges/vary_states/50_5_300_30.csv")

# %%
plt.scatter(random_states_50_300["Mutual Information of States"], random_states_50_300["variation_of_information"], label="random")
plt.scatter(pruned_states_50_300["Mutual Information of States"], pruned_states_50_300["variation_of_information"], label = "pruned")
plt.legend()

# %%
#scatter the random data
plt.scatter(random_states_50_300["Mutual Information of States"], random_states_50_300["retrievability"], label="random")
plt.scatter(pruned_states_50_300["Mutual Information of States"], pruned_states_50_300["retrievability"], label = "pruned")
plt.legend()

# %%
random_states_50_400 = pd.read_csv("random_edges/vary_states/50_5_400_30.csv")
pruned_states_50_400 = pd.read_csv("pruned_edges/vary_states/50_5_400_30.csv")

# %%
plt.scatter(random_states_50_400["Mutual Information of States"], random_states_50_400["variation_of_information"], label="random")
plt.scatter(pruned_states_50_400["Mutual Information of States"], pruned_states_50_400["variation_of_information"], label = "pruned")
plt.legend()

# %%
#scatter the random data
plt.scatter(random_states_50_400["Mutual Information of States"], random_states_50_400["retrievability"], label="random")
plt.scatter(pruned_states_50_400["Mutual Information of States"], pruned_states_50_400["retrievability"], label = "pruned")
plt.legend()

# %%
random_states_50_500 = pd.read_csv("random_edges/vary_states/50_5_500_30.csv")
pruned_states_50_500 = pd.read_csv("pruned_edges/vary_states/50_5_500_30.csv")

# %%
plt.scatter(random_states_50_500["Mutual Information of States"], random_states_50_500["variation_of_information"], label="random")
plt.scatter(pruned_states_50_500["Mutual Information of States"], pruned_states_50_500["variation_of_information"], label = "pruned")
plt.legend()

# %%
plt.scatter(random_states_50_500["Mutual Information of States"], random_states_50_500["retrievability"], label="random")
plt.scatter(pruned_states_50_500["Mutual Information of States"], pruned_states_50_500["retrievability"], label = "pruned")
plt.legend()

# %% [markdown]
# Not really sure what to make of this data. Going to draw a 3d scatter plot with free vars of edges and relatedness to see fully perf relationship.

# %%
random_states_both = pd.read_csv("random_edges/vary_edges_states/25_2_1000.csv")
pruned_states_both = pd.read_csv("pruned_edges/vary_edges_states/25_2_1000.csv")

# %%
#plot random 3d scatter
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(random_states_both["edges"], random_states_both["Mutual Information of States"], 
           random_states_both["retrievability"])

# %%
#plot pruned 3d scatter
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pruned_states_both["edges"], pruned_states_both["Mutual Information of States"], 
           pruned_states_both["retrievability"])

# %% [markdown]
# Plots are really not helpful so I'll use a 2d scatter plot with colored points

# %%
plt.scatter(random_states_both["edges"], 
            random_states_both["Mutual Information of States"], c = random_states_both["retrievability"], alpha = .5)
plt.colorbar()

# %%
plt.scatter(pruned_states_both["edges"], 
            pruned_states_both["Mutual Information of States"], c = pruned_states_both["retrievability"])
plt.colorbar()

# %% [markdown]
# Throwing up perf visualization for 20 nodes 2 states to compare with topologies.

# %%
random_20 = pd.read_csv("random_edges/vary_edges/20_2_10.csv")
random_20_avg, random_20_std = perf_summary_stats(random_20)

pruned_20 = pd.read_csv("pruned_edges/vary_edges/20_2_10.csv")
pruned_20_avg, pruned_20_std = perf_summary_stats(pruned_20)

# %%
#plots retrievability
plt.plot(random_20_avg.index, random_20_avg["retrievability"], label = "Random edges")
plt.plot(pruned_20_avg.index, pruned_20_avg["retrievability"], label = "Pruned edges")
plt.xlabel("Edges")
plt.ylabel("Retrievability")
plt.title("20 Nodes, 2 Stored State")
plt.legend()

# %% [markdown]
# 1. MCMC to see if clusters are the same.
# 2. See what kind of errors are making in the middling VI between states regime
# 3. Change number of stored states to see how changes number of connected components.

# %% [markdown]
# Testing the effect of rewiring some random prob of edges to see what happens

# %% [markdown]
# Lets shink down to only considering very small rewiring probs.

# %%
#30 nodes, 3 stored states, 95 edges
rewired_30_95 = pd.read_csv("pruned_edges/rewire/30_3_95_10.csv")
rewired_30_95_avg, rewired_30_95_std = perf_summary_stats(rewired_30_95, "Rewire Probability")
plt.plot(rewired_30_95_avg.index, rewired_30_95_avg)

# %% [markdown]
# Doesn't seem like there is a boost in perf for low rewire probs. Think this might change as I increase edge count (Since the clusters will be more dense).

# %%
#30 nodes, 3 stored states, 105 edges
rewired_30_105 = pd.read_csv("pruned_edges/rewire/30_3_105_10.csv")
rewired_30_105_avg, rewired_30_105_std = perf_summary_stats(rewired_30_105, "Rewire Probability")
plt.plot(rewired_30_105_avg.index, rewired_30_105_avg)

# %%
#30 nodes, 3 stored states, 115 edges
rewired_30_115 = pd.read_csv("pruned_edges/rewire/30_3_115_10.csv")
rewired_30_115_avg, rewired_30_115_std = perf_summary_stats(rewired_30_115, "Rewire Probability")
plt.plot(rewired_30_115_avg.index, rewired_30_115_avg)

# %% [markdown]
# Not really sure what's going on here, so going to both get performance stats and plot topologies to suss things out.

# %%
#perf stats
pruned_30_10 = pd.read_csv("pruned_edges/vary_edges/30_3_10.csv")
pruned_30_10_avg, pruned_30_10_std = perf_summary_stats(pruned_30_10)
#plots variation of info
plt.plot(pruned_30_10_avg.index, pruned_30_10_avg["retrievability"])
plt.xlabel("Edges")
plt.ylabel("Retrievability")
plt.title("30 Nodes, 3 Stored States");
